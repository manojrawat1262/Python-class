# %%
b=open('data1.csv','x')
b.close()

# %%
b=open('data1.csv','r')
print(b.read())
b.close()
# Out:
# sn,student name,course,state,phone,email id
# 1,Shivam Kumar,B.Tech(CSE),Bihar,9708226319,shivamkumar16121@gmail.com
# 2,Shahid Ahmad lone,B.Tech(CSE),J&K,6005011403,lonegowhar555@gmail.com
# 3,Aman Raj,B.Tech(CSE),Bihar,7903413102,aman933raj@gmail.com
# 4,Vishal Kumar,B.TechIT),Punjab,7973129467,leader.vishalkumar@gmail.com
# 5,Nitenj kumar,B.Tech(CSE),Punjab,8837639132,nitenj787@gmail.com
# 6,GAURAV KUMAR,B.Tech(CSE),Bihar,7488585702,gauravsft@gmail.com
# 7,Amit kumar,B.Tech(CSE),Punjab,7087869933,amityadav97876@gmail.com
# 8,Raghav Gupta,B.Tech(IT),Punjab,9877674153,graghav236@gmail.com
# 9,Saroj Kumar,B.Tech(CSE),Punjab,9060862382,1806625@ggi.ac.in
# 10,Shahid Gujar,B.Tech(CSE)Punjab,9116240211,shahidahimadgujar86@gmail.com
# 11,Raushan Kumar,B.Tech(CSE),Punjab,9122102491,raushansft@gmail.com
# 12,Amit Kumar,B.Tech(CSE),Jharkhand,8757126629,kumaramit207999@gmail.com
# 13,MD RAHMAT,B.Tech(IT),Bihar,9570102657,1815997@ggi.ac.in
# ...

# %%
df=pd.read_csv('data1.csv')
df
# Out:
#     sn         student name             course          state  \
# 0    1         Shivam Kumar        B.Tech(CSE)          Bihar
# 1    2    Shahid Ahmad lone        B.Tech(CSE)            J&K
# 2    3             Aman Raj        B.Tech(CSE)          Bihar
# 3    4         Vishal Kumar          B.TechIT)         Punjab
# 4    5         Nitenj kumar        B.Tech(CSE)         Punjab
# 5    6         GAURAV KUMAR        B.Tech(CSE)          Bihar
# 6    7           Amit kumar        B.Tech(CSE)         Punjab
# 7    8         Raghav Gupta         B.Tech(IT)         Punjab
# 8    9          Saroj Kumar        B.Tech(CSE)         Punjab
# 9   10         Shahid Gujar  B.Tech(CSE)Punjab     9116240211
# 10  11        Raushan Kumar        B.Tech(CSE)         Punjab
# 11  12           Amit Kumar        B.Tech(CSE)      Jharkhand
# 12  13            MD RAHMAT         B.Tech(IT)          Bihar
# 13  14          Sahid jamal        B.Tech(CSE)         Punjab
# ...

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',nrows=25)
df
# Out:
#     sn         student name             course       state  \
# 0    1         Shivam Kumar        B.Tech(CSE)       Bihar
# 1    2    Shahid Ahmad lone        B.Tech(CSE)         J&K
# 2    3             Aman Raj        B.Tech(CSE)       Bihar
# 3    4         Vishal Kumar          B.TechIT)      Punjab
# 4    5         Nitenj kumar        B.Tech(CSE)      Punjab
# 5    6         GAURAV KUMAR        B.Tech(CSE)       Bihar
# 6    7           Amit kumar        B.Tech(CSE)      Punjab
# 7    8         Raghav Gupta         B.Tech(IT)      Punjab
# 8    9          Saroj Kumar        B.Tech(CSE)      Punjab
# 9   10         Shahid Gujar  B.Tech(CSE)Punjab  9116240211
# 10  11        Raushan Kumar        B.Tech(CSE)      Punjab
# 11  12           Amit Kumar        B.Tech(CSE)   Jharkhand
# 12  13            MD RAHMAT         B.Tech(IT)       Bihar
# 13  14          Sahid jamal        B.Tech(CSE)      Punjab
# 14  15    Naresh Budhathoki        B.Tech(CSE)      Punjab
# ...

# %%
import pandas as pd 
df=pd.read_csv('data1.csv')
df
# Out:
#     sn         student name             course          state  \
# 0    1         Shivam Kumar        B.Tech(CSE)          Bihar
# 1    2    Shahid Ahmad lone        B.Tech(CSE)            J&K
# 2    3             Aman Raj        B.Tech(CSE)          Bihar
# 3    4         Vishal Kumar          B.TechIT)         Punjab
# 4    5         Nitenj kumar        B.Tech(CSE)         Punjab
# 5    6         GAURAV KUMAR        B.Tech(CSE)          Bihar
# 6    7           Amit kumar        B.Tech(CSE)         Punjab
# 7    8         Raghav Gupta         B.Tech(IT)         Punjab
# 8    9          Saroj Kumar        B.Tech(CSE)         Punjab
# 9   10         Shahid Gujar  B.Tech(CSE)Punjab     9116240211
# 10  11        Raushan Kumar        B.Tech(CSE)         Punjab
# 11  12           Amit Kumar        B.Tech(CSE)      Jharkhand
# 12  13            MD RAHMAT         B.Tech(IT)          Bihar
# 13  14          Sahid jamal        B.Tech(CSE)         Punjab
# ...

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',nrows=25,index_col='sn')
df
# Out:
#            student name             course       state  \
# sn
# 1          Shivam Kumar        B.Tech(CSE)       Bihar
# 2     Shahid Ahmad lone        B.Tech(CSE)         J&K
# 3              Aman Raj        B.Tech(CSE)       Bihar
# 4          Vishal Kumar          B.TechIT)      Punjab
# 5          Nitenj kumar        B.Tech(CSE)      Punjab
# 6          GAURAV KUMAR        B.Tech(CSE)       Bihar
# 7            Amit kumar        B.Tech(CSE)      Punjab
# 8          Raghav Gupta         B.Tech(IT)      Punjab
# 9           Saroj Kumar        B.Tech(CSE)      Punjab
# 10         Shahid Gujar  B.Tech(CSE)Punjab  9116240211
# 11        Raushan Kumar        B.Tech(CSE)      Punjab
# 12           Amit Kumar        B.Tech(CSE)   Jharkhand
# 13            MD RAHMAT         B.Tech(IT)       Bihar
# 14          Sahid jamal        B.Tech(CSE)      Punjab
# 15    Naresh Budhathoki        B.Tech(CSE)      Punjab
# 16        Abdul Mustafa         B.Tech(IT)      Punjab
# ...

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',nrows=30,index_col='sn')
df.head()
# Out:
#          student name       course   state       phone  \
# sn
# 1        Shivam Kumar  B.Tech(CSE)   Bihar  9708226319
# 2   Shahid Ahmad lone  B.Tech(CSE)     J&K  6005011403
# 3            Aman Raj  B.Tech(CSE)   Bihar  7903413102
# 4        Vishal Kumar    B.TechIT)  Punjab  7973129467
# 5        Nitenj kumar  B.Tech(CSE)  Punjab  8837639132
#
#                         email id
# sn
# 1     shivamkumar16121@gmail.com
# 2        lonegowhar555@gmail.com
# 3           aman933raj@gmail.com
# 4   leader.vishalkumar@gmail.com
# 5            nitenj787@gmail.com

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',nrows=25,index_col='sn')
df.tail()
# Out:
#            student name       course   state       phone  \
# sn
# 21         Neeraj kumar  B.Tech(CSE)  Punjab  9935081343
# 22    manoj kumar rawat  B.Tech(CSE)   nepal  8872735418
# 23      Harwinder Singh  B.Tech(CSE)  Punjab  8195930103
# 24         Palak kumari  B.Tech(CSE)  Punjab  8288872345
# 25  ISHFAQ Ahmad Thoker  B.Tech(CSE)     J&K  7780843245
#
#                         email id
# sn
# 21    neerajkumar78674@gmail.com
# 22              1806582@gg.ac.in
# 23       harryghatorey@gmail.com
# 24             1906372@ggi.ac.in
# 25  thokerishfaq970863@gmail.com

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',usecols=['sn','student name','state','course'],index_col='sn')
df.head()
# Out:
#          student name       course   state
# sn
# 1        Shivam Kumar  B.Tech(CSE)   Bihar
# 2   Shahid Ahmad lone  B.Tech(CSE)     J&K
# 3            Aman Raj  B.Tech(CSE)   Bihar
# 4        Vishal Kumar    B.TechIT)  Punjab
# 5        Nitenj kumar  B.Tech(CSE)  Punjab

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',index_col='sn')
df.iloc[1:5]
# Out:
#          student name       course   state       phone  \
# sn
# 2   Shahid Ahmad lone  B.Tech(CSE)     J&K  6005011403
# 3            Aman Raj  B.Tech(CSE)   Bihar  7903413102
# 4        Vishal Kumar    B.TechIT)  Punjab  7973129467
# 5        Nitenj kumar  B.Tech(CSE)  Punjab  8837639132
#
#                         email id
# sn
# 2        lonegowhar555@gmail.com
# 3           aman933raj@gmail.com
# 4   leader.vishalkumar@gmail.com
# 5            nitenj787@gmail.com

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',index_col='sn')
df.iloc[1:5,0:5]
# Out:
#          student name       course   state       phone  \
# sn
# 2   Shahid Ahmad lone  B.Tech(CSE)     J&K  6005011403
# 3            Aman Raj  B.Tech(CSE)   Bihar  7903413102
# 4        Vishal Kumar    B.TechIT)  Punjab  7973129467
# 5        Nitenj kumar  B.Tech(CSE)  Punjab  8837639132
#
#                         email id
# sn
# 2        lonegowhar555@gmail.com
# 3           aman933raj@gmail.com
# 4   leader.vishalkumar@gmail.com
# 5            nitenj787@gmail.com

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',index_col='sn')
df.loc[1:6]
# Out:
#          student name       course   state       phone  \
# sn
# 1        Shivam Kumar  B.Tech(CSE)   Bihar  9708226319
# 2   Shahid Ahmad lone  B.Tech(CSE)     J&K  6005011403
# 3            Aman Raj  B.Tech(CSE)   Bihar  7903413102
# 4        Vishal Kumar    B.TechIT)  Punjab  7973129467
# 5        Nitenj kumar  B.Tech(CSE)  Punjab  8837639132
# 6        GAURAV KUMAR  B.Tech(CSE)   Bihar  7488585702
#
#                         email id
# sn
# 1     shivamkumar16121@gmail.com
# 2        lonegowhar555@gmail.com
# 3           aman933raj@gmail.com
# 4   leader.vishalkumar@gmail.com
# 5            nitenj787@gmail.com
# 6            gauravsft@gmail.com

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',index_col='student name')
df.loc['Shivam Kumar':'manoj kumar rawat']
# Out:
#                    sn             course       state  \
# student name
# Shivam Kumar        1        B.Tech(CSE)       Bihar
# Shahid Ahmad lone   2        B.Tech(CSE)         J&K
# Aman Raj            3        B.Tech(CSE)       Bihar
# Vishal Kumar        4          B.TechIT)      Punjab
# Nitenj kumar        5        B.Tech(CSE)      Punjab
# GAURAV KUMAR        6        B.Tech(CSE)       Bihar
# Amit kumar          7        B.Tech(CSE)      Punjab
# Raghav Gupta        8         B.Tech(IT)      Punjab
# Saroj Kumar         9        B.Tech(CSE)      Punjab
# Shahid Gujar       10  B.Tech(CSE)Punjab  9116240211
# Raushan Kumar      11        B.Tech(CSE)      Punjab
# Amit Kumar         12        B.Tech(CSE)   Jharkhand
# MD RAHMAT          13         B.Tech(IT)       Bihar
# Sahid jamal        14        B.Tech(CSE)      Punjab
# Naresh Budhathoki  15        B.Tech(CSE)      Punjab
# Abdul Mustafa      16         B.Tech(IT)      Punjab
# ...

# %%
import pandas as pd 
df=pd.read_csv('data1.csv',index_col='sn')
df[df['state']=='nepal']
# Out:
#          student name       course  state       phone                email id
# sn
# 18         Sony Singh  B.Tech(CSE)  nepal  7217796983  sonyysingh56@gmail.com
# 22  manoj kumar rawat  B.Tech(CSE)  nepal  8872735418        1806582@gg.ac.in
# 34    Amit Raj Mouria  B.Tech(CSE)  nepal   931542369       1806536@ggi.ac.in
# 40     prashant thapa  B.Tech(CSE)  nepal  9814525507      18034602@ggi.ac.in
